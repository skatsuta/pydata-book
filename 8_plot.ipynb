# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(10))

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
from numpy.random import randn

# %%
plt.plot(randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)

# %%
fig

# %%
plt.plot(randn(50).cumsum(), 'ko--')

# %%
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = DataFrame(np.random.randn(10, 4).cumsum(0), columns=['A', 'B', 'C', 'D'], index=np.arange(0, 100, 10))
df.plot()

# %%
fig, axes = plt.subplots(2, 1)

# %%
data = Series(np.random.rand(16), index=list('abcdefghijklmnop'))

# %%
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)

# %%
fig

# %%
tips = pd.read_csv('ch08/tips.csv')

# %%
party_counts = pd.crosstab(tips.day, tips.size)

# %%
party_counts
# Out:
# col_0  1708
# day
# Fri      19
# Sat      87
# Sun      76
# Thur     62

# %%
party_counts.plot(kind='bar', stacked=True)

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips['tip_pct'].hist(bins=50)

# %%
tips['tip_pct'].plot('kde')

# %%
macro = pd.read_csv('ch08/macrodata.csv')

# %%
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]

# %%
trans_data = np.log(data).diff().dropna()

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
plt.scatter(trans_data['m1'], trans_data['unemp'])

# %%
plt.title('Changes in log %s vs. log %s' % ('m1', 'unemp'))

# %%
pd.scatter_matrix(trans_data, diagonal='kde', color='k', alpha=0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10d7f9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d9e9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d9747f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10da9c710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10dae82b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10db24358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10db6d400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dbae0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10dd0f278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dd58898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dd94e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10dde1a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10e81dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e86a780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e8a7828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e8ef710>]], dtype=object)
